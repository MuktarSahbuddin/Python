# %% [markdown]
# 7. Analisa Linier Regresion untuk user_id dan Gender

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings("ignore")

from google.colab import drive

drive.mount('/content/gdrive',force_remount=True)
root_path = 'gdrive/MyDrive/Jasa\Coding\Tugas/bootcamp_ruangguru/'  #change dir to your project folder
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
data = pd.read_csv('/content/gdrive/MyDrive/lm_output.csv"')

# %%
data.loc[data["gender"] == "M", "gender"] = 1

# %%
data.loc[data["gender"] == "F", "gender"] = 2

# %%
data["gender"] = data["gender"].astype(object).astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293236 entries, 0 to 1293235
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1293236 non-null  int64
#  1   first_name  1293236 non-null  object
#  2   gender      1293236 non-null  int64
#  3   user_id     1293236 non-null  float64
#  4   created_at  1293236 non-null  object
#  5   event_type  1293236 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 59.2+ MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
X = data.drop(['first_name','created_at','event_type','user_id'], axis = 1)
y = data['gender']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

logreg = LogisticRegression()
logreg = logreg.fit(X_train,y_train)
y_pred = logreg.predict(X_test)

# Import library
from sklearn.metrics import confusion_matrix, classification_report

#7. Print Confusion matrix dan classification report
print("\n[7] Print Confusion matrix dan classification report")

#apply confusion_matrix function to y_test and y_pred
print("Confusion matrix:")
cm = confusion_matrix(y_test,y_pred)
print(cm)

#apply classification_report function to y_test and y_pred
print("Classification report:")
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
# [7] Print Confusion matrix dan classification report
# Confusion matrix:
# [[130306      0]
#  [128342      0]]
# Classification report:
#               precision    recall  f1-score   support
#
#            1       0.50      1.00      0.67    130306
#            2       0.00      0.00      0.00    128342
#
#     accuracy                           0.50    258648
#    macro avg       0.25      0.50      0.34    258648
# weighted avg       0.25      0.50      0.34    258648
